# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# # My First Jupyter Notebook
#
# Is this working?.

# %% [markdown]
# ## Subheader (Idea: Headers)
#
# **Bold text** for emphasis.
#
# *Italic text* Cool.
#
# - Bullet list could be useful
# - Bullet list or not
#
# 1. Numbered list probably better
# 2. Another item
#
# [Link to GitHub Markdown Guide](https://docs.github.com/en/get-started/writing-on-github/getting-started-with-writing-and-formatting-on-github/basic-writing-and-formatting-syntax) (Idea: Links)
